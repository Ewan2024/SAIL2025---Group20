# %%
import pandas as pd
# copy relative path by right-clicking the file name on the explorer
vessel_data = pd.read_parquet('data/20250820163000_stream.vessel-positions-anonymized-processed.analyze-sail.parquet', engine='fastparquet')

# %%
vessel_data.head()
# Out:
#        _timestamp                                             _topic  \
# 0  1755671648.177  stream.vessel-positions-anonymized-processed.a...
# 1  1755671648.181  stream.vessel-positions-anonymized-processed.a...
# 2  1755671648.196  stream.vessel-positions-anonymized-processed.a...
# 3    1755671648.2  stream.vessel-positions-anonymized-processed.a...
# 4  1755671648.215  stream.vessel-positions-anonymized-processed.a...
#
#                                               _value  \
# 0  0AE4067B226964656E7469666965722D73656E736F7222...
# 1  0AD4067B226964656E7469666965722D73656E736F7222...
# 2  0ABD067B226964656E7469666965722D73656E736F7222...
# 3  0ABD067B226964656E7469666965722D73656E736F7222...
# 4  0AD6067B226964656E7469666965722D73656E736F7222...
#
#                                     _key   _offset _partition _connector_id  \
# 0  \n\n\n
# analyze-sail"testmytest  91242055          5          None
# 1  \n\n\n
# analyze-sail"testmytest  91242056          5          None
# ...
