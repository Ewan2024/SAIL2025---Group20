# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score
import os

# ML imports
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler
import joblib
import xgboost as xgb

# %%
# Read in crowd data
crowd_data = pd.read_csv('/Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/data/sensor_data.csv')

# %%
# Explore the Dataset
crowd_data.head()
# Out:
#                    timestamp  CMSA-GAKH-01_0  ...  weekday  is_weekend
# 0  2025-08-20 00:00:00+02:00              15  ...        2           0
# 1  2025-08-20 00:03:00+02:00               1  ...        2           0
# 2  2025-08-20 00:06:00+02:00               5  ...        2           0
# 3  2025-08-20 00:09:00+02:00               4  ...        2           0
# 4  2025-08-20 00:12:00+02:00               4  ...        2           0
#
# [5 rows x 81 columns]

# %%
crowd_data.tail()
# Out:
#                       timestamp  CMSA-GAKH-01_0  ...  weekday  is_weekend
# 2395  2025-08-24 23:45:00+02:00              11  ...        6           1
# 2396  2025-08-24 23:48:00+02:00               2  ...        6           1
# 2397  2025-08-24 23:51:00+02:00              10  ...        6           1
# 2398  2025-08-24 23:54:00+02:00               3  ...        6           1
# 2399  2025-08-24 23:57:00+02:00               6  ...        6           1
#
# [5 rows x 81 columns]

# %%
crowd_data.info
# Out:
# <bound method DataFrame.info of                       timestamp  CMSA-GAKH-01_0  ...  weekday  is_weekend
# 0     2025-08-20 00:00:00+02:00              15  ...        2           0
# 1     2025-08-20 00:03:00+02:00               1  ...        2           0
# 2     2025-08-20 00:06:00+02:00               5  ...        2           0
# 3     2025-08-20 00:09:00+02:00               4  ...        2           0
# 4     2025-08-20 00:12:00+02:00               4  ...        2           0
# ...                         ...             ...  ...      ...         ...
# 2395  2025-08-24 23:45:00+02:00              11  ...        6           1
# 2396  2025-08-24 23:48:00+02:00               2  ...        6           1
# 2397  2025-08-24 23:51:00+02:00              10  ...        6           1
# 2398  2025-08-24 23:54:00+02:00               3  ...        6           1
# 2399  2025-08-24 23:57:00+02:00               6  ...        6           1
#
# [2400 rows x 81 columns]>

# %%
crowd_data.describe()
# Out:
#        CMSA-GAKH-01_0  CMSA-GAKH-01_180  ...      weekday  is_weekend
# count     2400.000000       2400.000000  ...  2400.000000     2400.00
# mean        57.513750         49.180000  ...     4.000000        0.40
# std         69.204386         58.768898  ...     1.414508        0.49
# min          0.000000          0.000000  ...     2.000000        0.00
# 25%          3.000000          2.000000  ...     3.000000        0.00
# 50%         17.000000         15.000000  ...     4.000000        0.00
# 75%        110.250000         95.000000  ...     5.000000        1.00
# max        266.000000        257.000000  ...     6.000000        1.00
#
# [8 rows x 80 columns]

# %%
# Check for missing values 
crowd_data.isna().sum()
# Out:
# timestamp           0
# CMSA-GAKH-01_0      0
# CMSA-GAKH-01_180    0
# CMSA-GAWW-11_120    0
# CMSA-GAWW-11_300    0
#                    ..
# minute              0
# day                 0
# month               0
# weekday             0
# is_weekend          0
# Length: 81, dtype: int64

# %%
# Check duplicates
crowd_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
crowd_data.columns[1:-6]
# Out:
# Index(['CMSA-GAKH-01_0', 'CMSA-GAKH-01_180', 'CMSA-GAWW-11_120',
#        'CMSA-GAWW-11_300', 'CMSA-GAWW-12_115', 'CMSA-GAWW-12_295',
#        'CMSA-GAWW-13_120', 'CMSA-GAWW-13_300', 'CMSA-GAWW-14_40',
#        'CMSA-GAWW-14_220', 'CMSA-GAWW-15_30', 'CMSA-GAWW-15_210',
#        'CMSA-GAWW-16_30', 'CMSA-GAWW-16_210', 'CMSA-GAWW-17_40',
#        'CMSA-GAWW-17_220', 'CMSA-GAWW-19_115', 'CMSA-GAWW-19_295',
#        'CMSA-GAWW-20_120', 'CMSA-GAWW-20_300', 'CMSA-GAWW-21_120',
#        'CMSA-GAWW-21_300', 'CMSA-GAWW-23_109', 'CMSA-GAWW-23_289',
#        'GACM-04_50', 'GACM-04_230', 'GASA-01-A1_135', 'GASA-01-A1_315',
#        'GASA-01-A2_135', 'GASA-01-A2_315', 'GASA-01-B_135', 'GASA-01-B_315',
#        'GASA-01-C_135', 'GASA-01-C_315', 'GASA-02-01_135', 'GASA-02-01_315',
#        'GASA-02-02_135', 'GASA-02-02_315', 'GASA-03_105', 'GASA-03_285',
#        'GASA-04_135', 'GASA-04_315', 'GASA-05-O_135', 'GASA-05-O_315',
#        'GASA-05-W_135', 'GASA-05-W_315', 'GASA-06_95', 'GASA-06_275',
#        'GASA-06-B_95', 'GASA-06-B_275', 'GVCV-01_40', 'GVCV-01_220',
#        'GVCV-03_42', 'GVCV-03_222', 'GVCV-04_45', 'GVCV-04_225',
#        'GVCV-05-A_155', 'GVCV-05-A_335', 'GVCV-05-B_30', 'GVCV-05-B_210',
#        'GVCV-06_95', 'GVCV-06_275', 'GVCV-07_50', 'GVCV-07_230', 'GVCV-08_45',
#        'GVCV-08_225', 'GVCV-09_80', 'GVCV-09_260', 'GVCV-11_50', 'GVCV-11_230',
#        'GVCV-13_10', 'GVCV-13_190', 'GVCV-14_90', 'GVCV-14_270'],
#       dtype='object')

# %%
sensor_cols = [c for c in crowd_data.columns[1:-6]]
sensor_cols
# Out:
# ['CMSA-GAKH-01_0',
#  'CMSA-GAKH-01_180',
#  'CMSA-GAWW-11_120',
#  'CMSA-GAWW-11_300',
#  'CMSA-GAWW-12_115',
#  'CMSA-GAWW-12_295',
#  'CMSA-GAWW-13_120',
#  'CMSA-GAWW-13_300',
#  'CMSA-GAWW-14_40',
#  'CMSA-GAWW-14_220',
#  'CMSA-GAWW-15_30',
#  'CMSA-GAWW-15_210',
#  'CMSA-GAWW-16_30',
#  'CMSA-GAWW-16_210',
#  'CMSA-GAWW-17_40',
#  'CMSA-GAWW-17_220',
#  'CMSA-GAWW-19_115',
#  'CMSA-GAWW-19_295',
#  'CMSA-GAWW-20_120',
#  'CMSA-GAWW-20_300',
#  'CMSA-GAWW-21_120',
#  'CMSA-GAWW-21_300',
#  'CMSA-GAWW-23_109',
#  'CMSA-GAWW-23_289',
#  'GACM-04_50',
#  'GACM-04_230',
#  'GASA-01-A1_135',
#  'GASA-01-A1_315',
#  'GASA-01-A2_135',
#  'GASA-01-A2_315',
#  'GASA-01-B_135',
#  'GASA-01-B_315',
#  'GASA-01-C_135',
#  'GASA-01-C_315',
#  'GASA-02-01_135',
#  'GASA-02-01_315',
#  'GASA-02-02_135',
#  'GASA-02-02_315',
#  'GASA-03_105',
#  'GASA-03_285',
#  'GASA-04_135',
#  'GASA-04_315',
#  'GASA-05-O_135',
#  'GASA-05-O_315',
#  'GASA-05-W_135',
#  'GASA-05-W_315',
#  'GASA-06_95',
#  'GASA-06_275',
#  'GASA-06-B_95',
#  'GASA-06-B_275',
#  'GVCV-01_40',
#  'GVCV-01_220',
#  'GVCV-03_42',
#  'GVCV-03_222',
#  'GVCV-04_45',
#  'GVCV-04_225',
#  'GVCV-05-A_155',
#  'GVCV-05-A_335',
#  'GVCV-05-B_30',
#  'GVCV-05-B_210',
#  'GVCV-06_95',
#  'GVCV-06_275',
#  'GVCV-07_50',
#  'GVCV-07_230',
#  'GVCV-08_45',
#  'GVCV-08_225',
#  'GVCV-09_80',
#  'GVCV-09_260',
#  'GVCV-11_50',
#  'GVCV-11_230',
#  'GVCV-13_10',
#  'GVCV-13_190',
#  'GVCV-14_90',
#  'GVCV-14_270']

# %%
# Add total_crowd count per time stamp
crowd_data['total_crowd'] = crowd_data[sensor_cols].sum(axis=1)

# %%
crowd_data.head()
# Out:
#                    timestamp  CMSA-GAKH-01_0  ...  is_weekend  total_crowd
# 0  2025-08-20 00:00:00+02:00              15  ...           0          931
# 1  2025-08-20 00:03:00+02:00               1  ...           0          426
# 2  2025-08-20 00:06:00+02:00               5  ...           0          788
# 3  2025-08-20 00:09:00+02:00               4  ...           0          646
# 4  2025-08-20 00:12:00+02:00               4  ...           0          799
#
# [5 rows x 82 columns]

# %%
# Quick Overview - total crowd count over time
df = crowd_data

plt.figure(figsize=(14,5))
plt.plot(df['timestamp'], df['total_crowd'], lw=1.2)
plt.title("Total Crowd Count Over Time", fontsize=14)
plt.xlabel("Time")
plt.ylabel("Total Crowd Count")
plt.grid(alpha=0.3)
plt.show()

# %%
hourly_avg = df.groupby('hour')['total_crowd'].mean()

plt.figure(figsize=(10,5))
sns.barplot(x=hourly_avg.index, y=hourly_avg.values, color="skyblue")
plt.title("Average Crowd Count by Hour of Day")
plt.xlabel("Hour")
plt.ylabel("Average Crowd Count")
plt.show()

# %%
day_avg = df.groupby('weekday')['total_crowd'].mean()

plt.figure(figsize=(10,5))
sns.barplot(x=day_avg.index, y=day_avg.values, palette="viridis")
plt.title("Average Crowd Count by Day")
plt.xlabel("Day")
plt.ylabel("Average Crowd Count")
plt.show()
# Out:
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/414375696.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=day_avg.index, y=day_avg.values, palette="viridis")

# %%
# Read in weather data
weather_data = pd.read_csv('/Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/data/weather_data_cleaned.csv')

# %%
type(weather_data['timestamp'][0])
# Out:
# str

# %%
type(crowd_data['timestamp'][0])
# Out:
# str

# %%
crowd_data['timestamp'] = pd.to_datetime(crowd_data['timestamp'], utc=False)

# %%
type(crowd_data['timestamp'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
weather_data['timestamp'] = pd.to_datetime(weather_data['timestamp'], utc=False)

# %%
type(weather_data['timestamp'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# Merge crowd and weather data

merged_df = pd.merge_asof(
    crowd_data,
    weather_data,
    on = 'timestamp',
    direction = 'nearest',
    tolerance = pd.Timedelta('30min')
)

# %%
merged_df.head()
# Out:
#                   timestamp  CMSA-GAKH-01_0  ...  precipitation      condition
# 0 2025-08-20 00:00:00+02:00              15  ...            0.0  Mostly Cloudy
# 1 2025-08-20 00:03:00+02:00               1  ...            0.0  Mostly Cloudy
# 2 2025-08-20 00:06:00+02:00               5  ...            0.0  Mostly Cloudy
# 3 2025-08-20 00:09:00+02:00               4  ...            0.0  Mostly Cloudy
# 4 2025-08-20 00:12:00+02:00               4  ...            0.0  Mostly Cloudy
#
# [5 rows x 90 columns]

# %%
merged_df.to_csv(
    '/Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/data/crowd_weather_merged.csv',
    index=False
)

# %%
# === Settings ===
MERGED_CSV = '/Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/data/crowd_weather_merged.csv'
OUT_DIR = '/Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb'
os.makedirs(OUT_DIR, exist_ok=True)

PAST_HOURS = 1          # number of past hours to use as input
PREDICT_HORIZON = 1     # predict 1 hour ahead
STEP_HOURS = 1          # move window by 1 hour each sample
TEST_SPLIT = 0.05
CALIB_SPLIT = 0.15
TRAIN_SPLIT = 0.80

RANDOM_STATE = 42

# %%
# === Load merged df (already has crowd sensors + weather) ===
merged_df = pd.read_csv(MERGED_CSV, parse_dates=['timestamp'])

# %%
merged_df.columns[1:-15]
# Out:
# Index(['CMSA-GAKH-01_0', 'CMSA-GAKH-01_180', 'CMSA-GAWW-11_120',
#        'CMSA-GAWW-11_300', 'CMSA-GAWW-12_115', 'CMSA-GAWW-12_295',
#        'CMSA-GAWW-13_120', 'CMSA-GAWW-13_300', 'CMSA-GAWW-14_40',
#        'CMSA-GAWW-14_220', 'CMSA-GAWW-15_30', 'CMSA-GAWW-15_210',
#        'CMSA-GAWW-16_30', 'CMSA-GAWW-16_210', 'CMSA-GAWW-17_40',
#        'CMSA-GAWW-17_220', 'CMSA-GAWW-19_115', 'CMSA-GAWW-19_295',
#        'CMSA-GAWW-20_120', 'CMSA-GAWW-20_300', 'CMSA-GAWW-21_120',
#        'CMSA-GAWW-21_300', 'CMSA-GAWW-23_109', 'CMSA-GAWW-23_289',
#        'GACM-04_50', 'GACM-04_230', 'GASA-01-A1_135', 'GASA-01-A1_315',
#        'GASA-01-A2_135', 'GASA-01-A2_315', 'GASA-01-B_135', 'GASA-01-B_315',
#        'GASA-01-C_135', 'GASA-01-C_315', 'GASA-02-01_135', 'GASA-02-01_315',
#        'GASA-02-02_135', 'GASA-02-02_315', 'GASA-03_105', 'GASA-03_285',
#        'GASA-04_135', 'GASA-04_315', 'GASA-05-O_135', 'GASA-05-O_315',
#        'GASA-05-W_135', 'GASA-05-W_315', 'GASA-06_95', 'GASA-06_275',
#        'GASA-06-B_95', 'GASA-06-B_275', 'GVCV-01_40', 'GVCV-01_220',
#        'GVCV-03_42', 'GVCV-03_222', 'GVCV-04_45', 'GVCV-04_225',
#        'GVCV-05-A_155', 'GVCV-05-A_335', 'GVCV-05-B_30', 'GVCV-05-B_210',
#        'GVCV-06_95', 'GVCV-06_275', 'GVCV-07_50', 'GVCV-07_230', 'GVCV-08_45',
#        'GVCV-08_225', 'GVCV-09_80', 'GVCV-09_260', 'GVCV-11_50', 'GVCV-11_230',
#        'GVCV-13_10', 'GVCV-13_190', 'GVCV-14_90', 'GVCV-14_270'],
#       dtype='object')

# %%
# === Identify sensor columns and weather columns ===
sensor_cols = [c for c in merged_df.columns[1:-15]]
weather_cols = [c for c in merged_df.columns if c in ['temperature','precipitation','wind_speed','wind_gust','pressure','humidity','dew_point']]

# %%
sensor_cols
# Out:
# ['CMSA-GAKH-01_0',
#  'CMSA-GAKH-01_180',
#  'CMSA-GAWW-11_120',
#  'CMSA-GAWW-11_300',
#  'CMSA-GAWW-12_115',
#  'CMSA-GAWW-12_295',
#  'CMSA-GAWW-13_120',
#  'CMSA-GAWW-13_300',
#  'CMSA-GAWW-14_40',
#  'CMSA-GAWW-14_220',
#  'CMSA-GAWW-15_30',
#  'CMSA-GAWW-15_210',
#  'CMSA-GAWW-16_30',
#  'CMSA-GAWW-16_210',
#  'CMSA-GAWW-17_40',
#  'CMSA-GAWW-17_220',
#  'CMSA-GAWW-19_115',
#  'CMSA-GAWW-19_295',
#  'CMSA-GAWW-20_120',
#  'CMSA-GAWW-20_300',
#  'CMSA-GAWW-21_120',
#  'CMSA-GAWW-21_300',
#  'CMSA-GAWW-23_109',
#  'CMSA-GAWW-23_289',
#  'GACM-04_50',
#  'GACM-04_230',
#  'GASA-01-A1_135',
#  'GASA-01-A1_315',
#  'GASA-01-A2_135',
#  'GASA-01-A2_315',
#  'GASA-01-B_135',
#  'GASA-01-B_315',
#  'GASA-01-C_135',
#  'GASA-01-C_315',
#  'GASA-02-01_135',
#  'GASA-02-01_315',
#  'GASA-02-02_135',
#  'GASA-02-02_315',
#  'GASA-03_105',
#  'GASA-03_285',
#  'GASA-04_135',
#  'GASA-04_315',
#  'GASA-05-O_135',
#  'GASA-05-O_315',
#  'GASA-05-W_135',
#  'GASA-05-W_315',
#  'GASA-06_95',
#  'GASA-06_275',
#  'GASA-06-B_95',
#  'GASA-06-B_275',
#  'GVCV-01_40',
#  'GVCV-01_220',
#  'GVCV-03_42',
#  'GVCV-03_222',
#  'GVCV-04_45',
#  'GVCV-04_225',
#  'GVCV-05-A_155',
#  'GVCV-05-A_335',
#  'GVCV-05-B_30',
#  'GVCV-05-B_210',
#  'GVCV-06_95',
#  'GVCV-06_275',
#  'GVCV-07_50',
#  'GVCV-07_230',
#  'GVCV-08_45',
#  'GVCV-08_225',
#  'GVCV-09_80',
#  'GVCV-09_260',
#  'GVCV-11_50',
#  'GVCV-11_230',
#  'GVCV-13_10',
#  'GVCV-13_190',
#  'GVCV-14_90',
#  'GVCV-14_270']

# %%
weather_cols
# Out:
# ['temperature',
#  'dew_point',
#  'humidity',
#  'wind_speed',
#  'wind_gust',
#  'pressure',
#  'precipitation']

# %%
# === 1) Aggregate crowd to hourly sums (do not reassign merged_df -- create hourly_df) ===
# We aggregate sensor counts per hour (sum). Weather is averaged per hour (mean).
merged_df = merged_df.sort_values('timestamp').set_index('timestamp')

# %%
merged_df
# Out:
#                            CMSA-GAKH-01_0  ...      condition
# timestamp                                  ...
# 2025-08-20 00:00:00+02:00              15  ...  Mostly Cloudy
# 2025-08-20 00:03:00+02:00               1  ...  Mostly Cloudy
# 2025-08-20 00:06:00+02:00               5  ...  Mostly Cloudy
# 2025-08-20 00:09:00+02:00               4  ...  Mostly Cloudy
# 2025-08-20 00:12:00+02:00               4  ...  Mostly Cloudy
# ...                                   ...  ...            ...
# 2025-08-24 23:45:00+02:00              11  ...           Fair
# 2025-08-24 23:48:00+02:00               2  ...           Fair
# 2025-08-24 23:51:00+02:00              10  ...           Fair
# 2025-08-24 23:54:00+02:00               3  ...           Fair
# 2025-08-24 23:57:00+02:00               6  ...           Fair
#
# [2400 rows x 89 columns]

# %%
# Hourly weather mean (if available)
hourly_weather = merged_df[weather_cols].resample('1H').mean()
# Out:
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/458652203.py:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   hourly_weather = merged_df[weather_cols].resample('1H').mean()

# %%
hourly_weather
# Out:
#                            temperature  dew_point  ...     pressure  precipitation
# timestamp                                          ...
# 2025-08-20 00:00:00+02:00    17.222222  12.777778  ...  1014.562444            0.0
# 2025-08-20 01:00:00+02:00    17.222222  12.777778  ...  1014.562444            0.0
# 2025-08-20 02:00:00+02:00    17.222222  12.777778  ...  1014.562444            0.0
# 2025-08-20 03:00:00+02:00    17.222222  12.777778  ...  1014.562444            0.0
# 2025-08-20 04:00:00+02:00    17.222222  12.777778  ...  1014.562444            0.0
# ...                                ...        ...  ...          ...            ...
# 2025-08-24 19:00:00+02:00    18.777778  10.888889  ...  1020.319307            0.0
# 2025-08-24 20:00:00+02:00    17.611111  11.444444  ...  1020.319307            0.0
# 2025-08-24 21:00:00+02:00    16.333333  12.222222  ...  1020.624082            0.0
# 2025-08-24 22:00:00+02:00    15.777778  11.333333  ...  1021.335224            0.0
# 2025-08-24 23:00:00+02:00    14.111111  12.000000  ...  1020.522490            0.0
#
# [120 rows x 7 columns]

# %%
# Hourly sensors mean (if available)
hourly_sensors = merged_df[sensor_cols].resample('1H').mean()
# Out:
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/808865963.py:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   hourly_sensors = merged_df[sensor_cols].resample('1H').mean()

# %%
hourly_sensors
# Out:
#                            CMSA-GAKH-01_0  ...  GVCV-14_270
# timestamp                                  ...
# 2025-08-20 00:00:00+02:00            5.40  ...         0.05
# 2025-08-20 01:00:00+02:00            3.80  ...         0.25
# 2025-08-20 02:00:00+02:00            3.35  ...         0.00
# 2025-08-20 03:00:00+02:00            1.30  ...         0.00
# 2025-08-20 04:00:00+02:00            2.40  ...         0.00
# ...                                   ...  ...          ...
# 2025-08-24 19:00:00+02:00           91.70  ...        27.95
# 2025-08-24 20:00:00+02:00           37.95  ...        21.90
# 2025-08-24 21:00:00+02:00           23.05  ...        15.75
# 2025-08-24 22:00:00+02:00           15.55  ...        10.10
# 2025-08-24 23:00:00+02:00            6.50  ...         4.65
#
# [120 rows x 74 columns]

# %%
# Combine
hourly_df = pd.concat([hourly_sensors, hourly_weather], axis=1).reset_index()

# %%
hourly_df
# Out:
#                     timestamp  CMSA-GAKH-01_0  ...     pressure  precipitation
# 0   2025-08-20 00:00:00+02:00            5.40  ...  1014.562444            0.0
# 1   2025-08-20 01:00:00+02:00            3.80  ...  1014.562444            0.0
# 2   2025-08-20 02:00:00+02:00            3.35  ...  1014.562444            0.0
# 3   2025-08-20 03:00:00+02:00            1.30  ...  1014.562444            0.0
# 4   2025-08-20 04:00:00+02:00            2.40  ...  1014.562444            0.0
# ..                        ...             ...  ...          ...            ...
# 115 2025-08-24 19:00:00+02:00           91.70  ...  1020.319307            0.0
# 116 2025-08-24 20:00:00+02:00           37.95  ...  1020.319307            0.0
# 117 2025-08-24 21:00:00+02:00           23.05  ...  1020.624082            0.0
# 118 2025-08-24 22:00:00+02:00           15.55  ...  1021.335224            0.0
# 119 2025-08-24 23:00:00+02:00            6.50  ...  1020.522490            0.0
#
# [120 rows x 82 columns]

# %%
# === 2) Build sliding windows (past PAST_HOURS -> predict next hour) ===
def build_hourly_windows(df_hourly, sensor_cols, weather_cols, past_hours=1, predict_horizon=1):
    df = df_hourly.sort_values('timestamp').reset_index(drop=True)
    X_list = []
    y_list = []
    time_list = []

    n = len(df) #120 hours
    # earliest valid idx for t_end is past_hours -1, target index is t_end + predict_horizon
    for t_end in range(past_hours - 1, n - predict_horizon, STEP_HOURS):
        t_target = t_end + predict_horizon

        # Past window sensors: shape (past_hours, n_sensors)
        past_window = df.loc[t_end - (past_hours - 1): t_end, sensor_cols].fillna(0)
        # Flatten by hour-major order
        past_flat = past_window.values.flatten(order='C')  # length = past_hours * n_sensors

        # Aggregated summaries across the window (mean, std)
        past_mean = past_window.mean().values
        past_std = past_window.std().fillna(0).values

        # Weather at t_end (hourly) and optionally weather history can be added
        weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])

        # Time features for t_end
        ts = df.loc[t_end, 'timestamp']
        hour = pd.to_datetime(ts).hour
        dow = pd.to_datetime(ts).dayofweek
        is_weekend = int(dow >= 5)
        time_sin = np.sin(2 * np.pi * hour / 24.0)
        time_cos = np.cos(2 * np.pi * hour / 24.0)

        time_feats = np.array([hour, dow, is_weekend, time_sin, time_cos])

        # Compose feature vector
        feat = np.concatenate([past_flat, past_mean, past_std, weather_t, time_feats])
        X_list.append(feat)
        np.save(os.path.join(OUT_DIR, 'feature_order.npy'), np.array(feat))

        # Target: sensor values at t_target
        y_list.append(df.loc[t_target, sensor_cols].values)
        time_list.append(df.loc[t_target, 'timestamp'])

    X = np.vstack(X_list)
    y = np.vstack(y_list)
    times = np.array(time_list)
    return X, y, times

# %%
X, y, times = build_hourly_windows(hourly_df, sensor_cols, weather_cols, past_hours=PAST_HOURS, predict_horizon=PREDICT_HORIZON)
print("Created samples:", X.shape, "Targets:", y.shape)
# Out:
# Created samples: (119, 234) Targets: (119, 74)
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_10619/2548559668.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   weather_t = df.loc[t_end, weather_cols].fillna(0).values if len(weather_cols) > 0 else np.array([])

# %%
# === 3) Chronological split: 80% train / 15% calib / 5% test ===
n_samples = X.shape[0]
n_train = int(np.floor(TRAIN_SPLIT * n_samples))
n_calib = int(np.floor(CALIB_SPLIT * n_samples))
n_test = n_samples - n_train - n_calib

if n_test <= 0:
    raise ValueError("Not enough samples to split into requested sizes. Reduce calibration/test sizes or collect more data.")

idx_train_end = n_train
idx_calib_end = n_train + n_calib

X_train, y_train = X[:idx_train_end], y[:idx_train_end]
X_calib, y_calib = X[idx_train_end:idx_calib_end], y[idx_train_end:idx_calib_end]
X_test, y_test = X[idx_calib_end:], y[idx_calib_end:]

times_test = times[idx_calib_end:]

print("Splits: train", X_train.shape[0], "calib", X_calib.shape[0], "test", X_test.shape[0])
# Out:
# Splits: train 95 calib 17 test 7

# %%
# === 4) Scale features (fit scaler on train only) ===
scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train)
X_calib_s = scaler.transform(X_calib)
X_test_s = scaler.transform(X_test)
joblib.dump(scaler, os.path.join(OUT_DIR, 'scaler.joblib'))
# Out:
# ['/Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/scaler.joblib']

# %%
# === 5) Train XGBoost per sensor with early stopping on calibration set ===
models = {}
preds_test = np.zeros_like(y_test)
mae_per_sensor = []
r2_per_sensor = []

# %%
# XGBoost params
xgb_params = {
    'n_estimators': 1000,
    'learning_rate': 0.05,
    'max_depth': 6,
    'objective': 'reg:squarederror',
    'random_state': RANDOM_STATE,
    'verbosity': 0,
    'n_jobs': -1
}

# %%
for j, sensor in enumerate(sensor_cols):
    print(f"\nTraining sensor {j+1}/{len(sensor_cols)}: {sensor}")
    y_tr = y_train[:, j]
    y_cv = y_calib[:, j]
    y_te = y_test[:, j]

    # DMatrix optional, but we use sklearn API for early stopping convenience
    model = xgb.XGBRegressor(**xgb_params)

    # Fit with early stopping using calibration set as validation
    model.fit(
        X_train_s, y_tr,
        eval_set=[(X_calib_s, y_cv)],
        verbose=False
    )




    # Predict on test
    y_pred = model.predict(X_test_s)
    preds_test[:, j] = y_pred

    # Save model
    model_path = os.path.join(OUT_DIR, f'xgb_{sensor.replace("/", "_")}.joblib')
    joblib.dump(model, model_path)
    models[sensor] = model

    # Metrics
    mae = mean_absolute_error(y_te, y_pred)
    # r2 fallback (handle zero variance)
    ss_res = ((y_te - y_pred) ** 2).sum()
    ss_tot = ((y_te - y_te.mean()) ** 2).sum()
    r2 = 1 - ss_res / ss_tot if ss_tot != 0 else 0.0

    mae_per_sensor.append(mae)
    r2_per_sensor.append(r2)

    print(f"Saved {model_path}  MAE={mae:.3f}, R2={r2:.3f}")
# Out:
# Training sensor 1/74: CMSA-GAKH-01_0
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAKH-01_0.joblib  MAE=11.791, R2=0.957
#
# Training sensor 2/74: CMSA-GAKH-01_180
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAKH-01_180.joblib  MAE=7.536, R2=0.925
#
# Training sensor 3/74: CMSA-GAWW-11_120
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-11_120.joblib  MAE=12.286, R2=-0.279
#
# Training sensor 4/74: CMSA-GAWW-11_300
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-11_300.joblib  MAE=14.980, R2=-1.648
#
# Training sensor 5/74: CMSA-GAWW-12_115
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-12_115.joblib  MAE=35.216, R2=-12.039
#
# Training sensor 6/74: CMSA-GAWW-12_295
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-12_295.joblib  MAE=6.441, R2=0.650
#
# Training sensor 7/74: CMSA-GAWW-13_120
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-13_120.joblib  MAE=9.234, R2=0.216
#
# Training sensor 8/74: CMSA-GAWW-13_300
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-13_300.joblib  MAE=9.030, R2=0.131
#
# Training sensor 9/74: CMSA-GAWW-14_40
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-14_40.joblib  MAE=3.169, R2=-1.426
#
# Training sensor 10/74: CMSA-GAWW-14_220
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-14_220.joblib  MAE=3.064, R2=-1.369
#
# Training sensor 11/74: CMSA-GAWW-15_30
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-15_30.joblib  MAE=12.369, R2=0.170
#
# Training sensor 12/74: CMSA-GAWW-15_210
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-15_210.joblib  MAE=9.726, R2=0.637
#
# Training sensor 13/74: CMSA-GAWW-16_30
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-16_30.joblib  MAE=7.452, R2=0.740
#
# Training sensor 14/74: CMSA-GAWW-16_210
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-16_210.joblib  MAE=8.697, R2=0.266
#
# Training sensor 15/74: CMSA-GAWW-17_40
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-17_40.joblib  MAE=3.530, R2=0.820
#
# Training sensor 16/74: CMSA-GAWW-17_220
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-17_220.joblib  MAE=10.350, R2=-1.566
#
# Training sensor 17/74: CMSA-GAWW-19_115
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-19_115.joblib  MAE=9.595, R2=0.220
#
# Training sensor 18/74: CMSA-GAWW-19_295
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-19_295.joblib  MAE=13.223, R2=-4.584
#
# Training sensor 19/74: CMSA-GAWW-20_120
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-20_120.joblib  MAE=2.672, R2=0.000
#
# Training sensor 20/74: CMSA-GAWW-20_300
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-20_300.joblib  MAE=1.222, R2=0.000
#
# Training sensor 21/74: CMSA-GAWW-21_120
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-21_120.joblib  MAE=24.723, R2=-0.976
#
# Training sensor 22/74: CMSA-GAWW-21_300
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-21_300.joblib  MAE=33.956, R2=-3.595
#
# Training sensor 23/74: CMSA-GAWW-23_109
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-23_109.joblib  MAE=5.291, R2=-0.046
#
# Training sensor 24/74: CMSA-GAWW-23_289
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_CMSA-GAWW-23_289.joblib  MAE=6.303, R2=-1.364
#
# Training sensor 25/74: GACM-04_50
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GACM-04_50.joblib  MAE=18.500, R2=0.683
#
# Training sensor 26/74: GACM-04_230
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GACM-04_230.joblib  MAE=31.448, R2=0.526
#
# Training sensor 27/74: GASA-01-A1_135
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-01-A1_135.joblib  MAE=5.342, R2=-2.454
#
# Training sensor 28/74: GASA-01-A1_315
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-01-A1_315.joblib  MAE=5.661, R2=-0.918
#
# Training sensor 29/74: GASA-01-A2_135
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-01-A2_135.joblib  MAE=15.597, R2=-1.595
#
# Training sensor 30/74: GASA-01-A2_315
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-01-A2_315.joblib  MAE=20.966, R2=-1.116
#
# Training sensor 31/74: GASA-01-B_135
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-01-B_135.joblib  MAE=4.194, R2=0.259
#
# Training sensor 32/74: GASA-01-B_315
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-01-B_315.joblib  MAE=22.150, R2=-2.502
#
# Training sensor 33/74: GASA-01-C_135
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-01-C_135.joblib  MAE=15.687, R2=0.569
#
# Training sensor 34/74: GASA-01-C_315
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-01-C_315.joblib  MAE=2.752, R2=0.464
#
# Training sensor 35/74: GASA-02-01_135
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-02-01_135.joblib  MAE=3.207, R2=0.599
#
# Training sensor 36/74: GASA-02-01_315
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-02-01_315.joblib  MAE=103.779, R2=-1.330
#
# Training sensor 37/74: GASA-02-02_135
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-02-02_135.joblib  MAE=59.543, R2=-3.518
#
# Training sensor 38/74: GASA-02-02_315
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-02-02_315.joblib  MAE=9.336, R2=0.534
#
# Training sensor 39/74: GASA-03_105
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-03_105.joblib  MAE=23.894, R2=-0.661
#
# Training sensor 40/74: GASA-03_285
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-03_285.joblib  MAE=95.670, R2=-3.909
#
# Training sensor 41/74: GASA-04_135
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-04_135.joblib  MAE=19.685, R2=-0.685
#
# Training sensor 42/74: GASA-04_315
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-04_315.joblib  MAE=26.724, R2=0.422
#
# Training sensor 43/74: GASA-05-O_135
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-05-O_135.joblib  MAE=2.756, R2=0.784
#
# Training sensor 44/74: GASA-05-O_315
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-05-O_315.joblib  MAE=4.342, R2=0.529
#
# Training sensor 45/74: GASA-05-W_135
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-05-W_135.joblib  MAE=5.296, R2=0.364
#
# Training sensor 46/74: GASA-05-W_315
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-05-W_315.joblib  MAE=2.179, R2=0.388
#
# Training sensor 47/74: GASA-06_95
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-06_95.joblib  MAE=0.000, R2=0.000
#
# Training sensor 48/74: GASA-06_275
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-06_275.joblib  MAE=0.000, R2=0.000
#
# Training sensor 49/74: GASA-06-B_95
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-06-B_95.joblib  MAE=2.000, R2=0.403
#
# Training sensor 50/74: GASA-06-B_275
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GASA-06-B_275.joblib  MAE=2.870, R2=-21.088
#
# Training sensor 51/74: GVCV-01_40
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-01_40.joblib  MAE=7.890, R2=-0.219
#
# Training sensor 52/74: GVCV-01_220
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-01_220.joblib  MAE=5.348, R2=0.136
#
# Training sensor 53/74: GVCV-03_42
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-03_42.joblib  MAE=5.362, R2=0.176
#
# Training sensor 54/74: GVCV-03_222
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-03_222.joblib  MAE=9.812, R2=0.392
#
# Training sensor 55/74: GVCV-04_45
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-04_45.joblib  MAE=8.972, R2=-0.855
#
# Training sensor 56/74: GVCV-04_225
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-04_225.joblib  MAE=8.123, R2=0.393
#
# Training sensor 57/74: GVCV-05-A_155
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-05-A_155.joblib  MAE=15.342, R2=-0.349
#
# Training sensor 58/74: GVCV-05-A_335
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-05-A_335.joblib  MAE=16.480, R2=-3.360
#
# Training sensor 59/74: GVCV-05-B_30
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-05-B_30.joblib  MAE=6.723, R2=-0.331
#
# Training sensor 60/74: GVCV-05-B_210
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-05-B_210.joblib  MAE=4.863, R2=0.852
#
# Training sensor 61/74: GVCV-06_95
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-06_95.joblib  MAE=3.687, R2=-0.682
#
# Training sensor 62/74: GVCV-06_275
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-06_275.joblib  MAE=7.006, R2=-0.350
#
# Training sensor 63/74: GVCV-07_50
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-07_50.joblib  MAE=1.216, R2=0.821
#
# Training sensor 64/74: GVCV-07_230
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-07_230.joblib  MAE=2.008, R2=0.840
#
# Training sensor 65/74: GVCV-08_45
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-08_45.joblib  MAE=2.623, R2=-0.991
#
# Training sensor 66/74: GVCV-08_225
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-08_225.joblib  MAE=1.474, R2=0.505
#
# Training sensor 67/74: GVCV-09_80
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-09_80.joblib  MAE=0.094, R2=0.000
#
# Training sensor 68/74: GVCV-09_260
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-09_260.joblib  MAE=0.045, R2=-5.520
#
# Training sensor 69/74: GVCV-11_50
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-11_50.joblib  MAE=8.157, R2=0.636
#
# Training sensor 70/74: GVCV-11_230
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-11_230.joblib  MAE=15.010, R2=0.620
#
# Training sensor 71/74: GVCV-13_10
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-13_10.joblib  MAE=6.723, R2=0.764
#
# Training sensor 72/74: GVCV-13_190
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-13_190.joblib  MAE=11.263, R2=0.649
#
# Training sensor 73/74: GVCV-14_90
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-14_90.joblib  MAE=5.112, R2=0.818
#
# Training sensor 74/74: GVCV-14_270
# Saved /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_GVCV-14_270.joblib  MAE=7.630, R2=0.707

# %%
# === 6) Summary metrics ===
mae_per_sensor = np.array(mae_per_sensor)
r2_per_sensor = np.array(r2_per_sensor)

print("\n=== Summary ===")
print("Overall MAE (mean across sensors):", mae_per_sensor.mean())
print("Overall R2  (mean across sensors):", r2_per_sensor.mean())

# Show top 5 worst sensors by MAE
worst_idx = np.argsort(mae_per_sensor)[-5:][::-1]
print("\nTop 5 sensors by MAE (worst):")
for ix in worst_idx:
    print(sensor_cols[ix], "MAE=", mae_per_sensor[ix], "R2=", r2_per_sensor[ix])
# Out:
# === Summary ===
# Overall MAE (mean across sensors): 250.38171913771455
# Overall R2  (mean across sensors): -0.7974025484164724
#
# Top 5 sensors by MAE (worst):
# GASA-02-01_315 MAE= 2076.091064453125 R2= -1.3310567164844742
# GASA-03_285 MAE= 1913.275634765625 R2= -3.9081326720760057
# GASA-02-02_135 MAE= 1191.015869140625 R2= -3.5191703134494494
# CMSA-GAWW-12_115 MAE= 704.2864379882812 R2= -12.039174304085716
# CMSA-GAWW-21_300 MAE= 679.2847290039062 R2= -3.5966138812827237

# %%
# === 7) Save test predictions vs actuals for inspection ===
out_df = pd.DataFrame({'timestamp': times_test})
for j, s in enumerate(sensor_cols):
    out_df[f"{s}_actual"] = y_test[:, j]
    out_df[f"{s}_xgb_pred"] = preds_test[:, j]

out_csv = os.path.join(OUT_DIR, 'xgb_test_preds_vs_actuals.csv')
out_df.to_csv(out_csv, index=False)
print("Saved test predictions to:", out_csv)
# Out:
# Saved test predictions to: /Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/models_xgb/xgb_test_preds_vs_actuals.csv
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_actual"] = y_test[:, j]
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_61657/3374055806.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out_df[f"{s}_xgb_pred"] = preds_test[:, j]

# %%
print(xgb.__version__)
# Out:
# 3.1.0

# %%
# === Settings ===
sensor_to_plot = 'CMSA-GAKH-01_0'  # change to any sensor you like
n_plot_hours = 48  # number of hours to plot, optional

# Find sensor index
sensor_idx = sensor_cols.index(sensor_to_plot)

# Extract actual and predicted values
y_actual = y_test[:, sensor_idx]
y_predicted = preds_test[:, sensor_idx]
timestamps_plot = times_test

# If you want to zoom on the first n_plot_hours
timestamps_plot = timestamps_plot[:n_plot_hours]
y_actual = y_actual[:n_plot_hours]
y_predicted = y_predicted[:n_plot_hours]

# === Plot ===
plt.figure(figsize=(15,5))
sns.set_style("whitegrid")

plt.plot(timestamps_plot, y_actual, marker='o', linestyle='-', label='Actual', color='blue')
plt.plot(timestamps_plot, y_predicted, marker='x', linestyle='--', label='Predicted', color='red')

plt.title(f'Actual vs Predicted Crowd Count for {sensor_to_plot}')
plt.xlabel('Timestamp')
plt.ylabel('Crowd Count')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# === Settings ===
sensor_to_plot = 'GASA-02-01_315'  # change to any sensor you like
n_plot_hours = 48  # number of hours to plot, optional

# Find sensor index
sensor_idx = sensor_cols.index(sensor_to_plot)

# Extract actual and predicted values
y_actual = y_test[:, sensor_idx]
y_predicted = preds_test[:, sensor_idx]
timestamps_plot = times_test

# If you want to zoom on the first n_plot_hours
timestamps_plot = timestamps_plot[:n_plot_hours]
y_actual = y_actual[:n_plot_hours]
y_predicted = y_predicted[:n_plot_hours]

# === Plot ===
plt.figure(figsize=(15,5))
sns.set_style("whitegrid")

plt.plot(timestamps_plot, y_actual, marker='o', linestyle='-', label='Actual', color='blue')
plt.plot(timestamps_plot, y_predicted, marker='x', linestyle='--', label='Predicted', color='red')

plt.title(f'Actual vs Predicted Crowd Count for {sensor_to_plot}')
plt.xlabel('Timestamp')
plt.ylabel('Crowd Count')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
