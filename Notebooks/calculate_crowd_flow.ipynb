# %%
import pandas as pd
from data_loader import load_sensor_locations
from data_loader import load_sensor_data


# load data sets
sensor_data = load_sensor_data()
sensor_locations = load_sensor_locations()


# create empty data frame
crowd_flow = pd.DataFrame()


# add column names and remove useless columns
column_names = sensor_data.columns
for i in column_names:
    crowd_flow[i] = ()

remove_columns = ["hour", "minute", "day", "month", "weekday", "is_weekend"]
for i in remove_columns:
    crowd_flow = crowd_flow.drop(columns=i)


# sets index to column timestamp so the function can later add rows to this data frame
crowd_flow.set_index("timestamp", inplace=True)


# the data in sensor_locations is stored with a "," instead of a "." and first needs to be converted to a float value
sensor_locations["Effectieve  breedte"] = sensor_locations["Effectieve  breedte"].str.replace(",", ".").astype(float)


# function to add rows with calculated crowd flow data to crowd_flow
def calculate_crowd_flow(timestamp):
    # gets the index of the respective row
    row = sensor_data.index[sensor_data['timestamp'] == timestamp]
    #list wich will be added to the dataframe
    flow_data = []

    for i in crowd_flow.columns:
        if i == "timestamp":
            continue

        another_row = sensor_locations.index[sensor_locations['sensor_id_full'] == i]

        # empty rows might mess up the length of the list that will be appended, therefore an empty placeholder is added instead
        if sensor_data[sensor_data['timestamp'] == timestamp].empty or sensor_locations[sensor_locations['sensor_id_full'] == i].empty:
            flow_data.append(None)
            continue

        # number of people / width / time(3 mins)
        flow_number = int(sensor_data.loc[row, i]) / float(sensor_locations.loc[another_row, "Effectieve  breedte"]) / 3
        flow_data.append(flow_number)

    crowd_flow.loc[timestamp] = flow_data


for i in sensor_data["timestamp"].head(5):
    calculate_crowd_flow(i)


crowd_flow
# Out:
# C:\Users\cniss\AppData\Local\Temp\ipykernel_29204\1346318106.py:52: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   flow_number = int(sensor_data.loc[row, i]) / float(sensor_locations.loc[another_row, "Effectieve  breedte"]) / 3
# C:\Users\cniss\AppData\Local\Temp\ipykernel_29204\1346318106.py:52: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   flow_number = int(sensor_data.loc[row, i]) / float(sensor_locations.loc[another_row, "Effectieve  breedte"]) / 3
# C:\Users\cniss\AppData\Local\Temp\ipykernel_29204\1346318106.py:52: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   flow_number = int(sensor_data.loc[row, i]) / float(sensor_locations.loc[another_row, "Effectieve  breedte"]) / 3
# C:\Users\cniss\AppData\Local\Temp\ipykernel_29204\1346318106.py:52: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   flow_number = int(sensor_data.loc[row, i]) / float(sensor_locations.loc[another_row, "Effectieve  breedte"]) / 3
# C:\Users\cniss\AppData\Local\Temp\ipykernel_29204\1346318106.py:52: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   flow_number = int(sensor_data.loc[row, i]) / float(sensor_locations.loc[another_row, "Effectieve  breedte"]) / 3
# C:\Users\cniss\AppData\Local\Temp\ipykernel_29204\1346318106.py:52: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   flow_number = int(sensor_data.loc[row, i]) / float(sensor_locations.loc[another_row, "Effectieve  breedte"]) / 3
# C:\Users\cniss\AppData\Local\Temp\ipykernel_29204\1346318106.py:52: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   flow_number = int(sensor_data.loc[row, i]) / float(sensor_locations.loc[another_row, "Effectieve  breedte"]) / 3
# C:\Users\cniss\AppData\Local\Temp\ipykernel_29204\1346318106.py:52: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   flow_number = int(sensor_data.loc[row, i]) / float(sensor_locations.loc[another_row, "Effectieve  breedte"]) / 3
# C:\Users\cniss\AppData\Local\Temp\ipykernel_29204\1346318106.py:52: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   flow_number = int(sensor_data.loc[row, i]) / float(sensor_locations.loc[another_row, "Effectieve  breedte"]) / 3
# C:\Users\cniss\AppData\Local\Temp\ipykernel_29204\1346318106.py:52: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   flow_number = int(sensor_data.loc[row, i]) / float(sensor_locations.loc[another_row, "Effectieve  breedte"]) / 3
#                            CMSA-GAKH-01_0  CMSA-GAKH-01_180  CMSA-GAWW-11_120  \
# timestamp
# 2025-08-20 00:00:00+02:00        0.746269          0.199005          2.843137
# 2025-08-20 00:03:00+02:00        0.049751          0.149254          2.058824
# 2025-08-20 00:06:00+02:00        0.248756          0.199005          3.431373
# 2025-08-20 00:09:00+02:00        0.199005          0.199005          3.921569
# 2025-08-20 00:12:00+02:00        0.199005          0.547264          5.294118
#
#                            CMSA-GAWW-11_300  CMSA-GAWW-12_115  \
# timestamp
# 2025-08-20 00:00:00+02:00          3.235294          5.641026
# 2025-08-20 00:03:00+02:00          2.843137          4.358974
# 2025-08-20 00:06:00+02:00          2.156863          3.717949
# 2025-08-20 00:09:00+02:00          4.607843          5.384615
# 2025-08-20 00:12:00+02:00          5.784314          7.435897
#
#                            CMSA-GAWW-12_295  CMSA-GAWW-13_120  \
# timestamp
# 2025-08-20 00:00:00+02:00          3.589744          6.363636
# 2025-08-20 00:03:00+02:00          5.000000          1.363636
# 2025-08-20 00:06:00+02:00          4.358974          5.000000
# 2025-08-20 00:09:00+02:00          5.128205          2.878788
# 2025-08-20 00:12:00+02:00          4.230769          2.575758
#
#                            CMSA-GAWW-13_300  CMSA-GAWW-14_40  \
# timestamp
# 2025-08-20 00:00:00+02:00          5.606061         1.018519
# 2025-08-20 00:03:00+02:00          2.121212         0.555556
# 2025-08-20 00:06:00+02:00          6.363636         1.296296
# 2025-08-20 00:09:00+02:00          5.151515         1.388889
# 2025-08-20 00:12:00+02:00          5.000000         2.407407
#
#                            CMSA-GAWW-14_220  ...  GVCV-08_45  GVCV-08_225  \
# timestamp                                    ...
# 2025-08-20 00:00:00+02:00          0.277778  ...    0.215054          0.0
# 2025-08-20 00:03:00+02:00          0.555556  ...    0.000000          0.0
# 2025-08-20 00:06:00+02:00          0.277778  ...    0.000000          0.0
# 2025-08-20 00:09:00+02:00          0.185185  ...    0.000000          0.0
# 2025-08-20 00:12:00+02:00          0.833333  ...    0.000000          0.0
#
#                            GVCV-09_80  GVCV-09_260  GVCV-11_50  GVCV-11_230  \
# timestamp
# 2025-08-20 00:00:00+02:00         0.0          0.0    5.913978     6.344086
# 2025-08-20 00:03:00+02:00         0.0          0.0    0.000000     1.182796
# 2025-08-20 00:06:00+02:00         0.0          0.0    0.000000     0.000000
# 2025-08-20 00:09:00+02:00         0.0          0.0    0.000000     0.000000
# 2025-08-20 00:12:00+02:00         0.0          0.0    0.000000     0.000000
#
#                            GVCV-13_10  GVCV-13_190  GVCV-14_90  GVCV-14_270
# timestamp
# 2025-08-20 00:00:00+02:00    4.408602     4.301075         0.0          0.0
# 2025-08-20 00:03:00+02:00    0.000000     0.000000         0.0          0.0
# 2025-08-20 00:06:00+02:00    0.000000     0.000000         0.0          0.0
# 2025-08-20 00:09:00+02:00    0.000000     0.000000         0.0          0.0
# 2025-08-20 00:12:00+02:00   13.655914     6.129032         0.0          0.0
#
# [5 rows x 74 columns]
