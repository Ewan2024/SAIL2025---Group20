# %%
import geopandas as gpd

# %%
def load_tram_metro_data():
    url = "https://maps.amsterdam.nl/open_geodata/geojson_latlng.php?KAARTLAAG=TRAMMETRO_PUNTEN_2025&THEMA=trammetro"
    gdf = gpd.read_file(url)
    return gdf

tram_metro_gdf = load_tram_metro_data()
tram_metro_gdf
# Out:
#                               Naam Modaliteit         Lijn Lijn_select  \
# 0                 Nieuwezijds Kolk       Tram  2 | 12 | 17    02|12|17
# 1    Surinameplein / Curaçaostraat       Tram  1 | 17 | 27    01|17|27
# 2               Johan Huizingalaan       Tram  1 | 17 | 27    01|17|27
# 3                    Prinsengracht       Tram  2 | 12 | 17    02|12|17
# 4                     Keizergracht       Tram  2 | 12 | 17    02|12|17
# ..                             ...        ...          ...         ...
# 227                    Aan de Zoom       Tram           25          25
# 228               Uithoorn Station       Tram           25          25
# 229               Uithoorn Centrum       Tram           25          25
# 230                            Dam       Tram  2 | 12 | 17    02|12|27
# 231              Albert Cuypstraat       Tram            4          04
#
#      RADIUS                                        Label  \
# 0         5               2 | 12 | 17 - Nieuwezijds Kolk
# 1         5  1 | 17 | 27 - Surinameplein / Curaçaostraat
# 2         5             1 | 17 | 27 - Johan Huizingalaan
# 3         5                  2 | 12 | 17 - Prinsengracht
# 4         5                   2 | 12 | 17 - Keizergracht
# ..      ...                                          ...
# 227       5                             25 - Aan de Zoom
# 228       5                        25 - Uithoorn Station
# 229       5                        25 - Uithoorn Centrum
# 230       5                            2 | 12 | 17 - Dam
# 231       5                        4 - Albert Cuypstraat
#
#                      geometry
# 0    POINT (52.37607 4.89334)
# 1    POINT (52.35838 4.85312)
# 2    POINT (52.35782 4.82732)
# 3    POINT (52.36502 4.88447)
# 4    POINT (52.36596 4.88645)
# ..                        ...
# 227  POINT (52.24896 4.81175)
# 228  POINT (52.24313 4.82132)
# 229   POINT (52.2352 4.83437)
# 230  POINT (52.37457 4.89149)
# 231  POINT (52.35742 4.89945)
#
# [232 rows x 7 columns]

# %%
for _, row in tram_metro_gdf.iterrows():
        # print(row)
        # print(row.geometry)
        print(row.geometry.coords[0])
# Out:
# (52.376071, 4.893344)
# (52.358384, 4.853117)
# (52.357816, 4.827325)
# (52.365024, 4.884466)
# (52.365963, 4.886446)
# (52.3678894, 4.8891545)
# (52.353745, 4.774775)
# (52.352917, 4.776846)
# (52.350338, 4.783287)
# (52.350985, 4.794747)
# (52.352505, 4.802256)
# (52.353897, 4.808843)
# (52.362752, 4.875287)
# (52.358968, 4.860096)
# (52.347758, 4.94019)
# (52.343074, 4.947649)
# (52.33961, 4.954533)
# (52.3382985, 4.9612609)
# (52.336763, 4.969577)
# (52.361019, 4.929368)
# (52.356401, 4.810137)
# (52.357957, 4.840032)
# (52.361472, 4.853279)
# (52.364245, 4.8534365)
# (52.3656403, 4.8661709)
# (52.367246, 4.872164)
# (52.3637101, 4.8820313)
# (52.349776, 4.788597)
# (52.360454, 4.866245)
# (52.384237, 4.869865)
# (52.381498, 4.881058)
# (52.376743, 4.937331)
# (52.381325, 4.821459)
# (52.384362, 4.875041)
# (52.368273, 4.926459)
# (52.373506, 4.938455)
# (52.362487, 4.91432)
# (52.359632, 4.890943)
# (52.3608311, 4.887386)
# (52.385044, 4.883588)
# (52.383185, 4.877048)
# (52.38114, 4.879189)
# (52.363606, 4.918929)
# (52.366772, 4.924559)
# (52.370258, 4.929691)
# (52.372899, 4.934361)
# (52.370537, 4.863925)
# (52.35279, 4.891107)
# (52.382574, 4.851309)
# (52.385888, 4.846416)
# (52.340218, 4.891987)
# (52.344529, 4.900811)
# (52.342999, 4.89659)
# (52.34191, 4.89304)
# (52.301255, 4.867279)
# (52.37092, 4.85536)
# (52.37469, 4.85856)
# (52.3721346, 4.8757656)
# (52.352858, 4.882355)
# (52.380563, 4.854869)
# (52.346939, 4.895126)
# (52.346697, 4.899972)
# (52.350197, 4.891543)
# (52.3721576, 4.8906471)
# (52.376429, 4.812448)
# (52.379721, 4.832243)
# (52.380571, 4.826824)
# (52.374411, 4.827313)
# (52.369434, 4.844117)
# (52.376945, 4.806463)
# (52.377261, 4.803269)
# (52.370039, 4.850261)
# (52.369648, 4.838204)
# (52.372849, 4.818873)
# (52.366244, 4.896573)
# (52.366628, 4.91117)
# (52.375695, 4.81902)
# (52.365172, 4.951398)
# (52.367822, 4.905698)
# (52.361919, 4.92398)
# (52.360018, 4.925295)
# (52.364873, 4.947752)
# (52.371488, 4.838105)
# (52.377877, 4.845748)
# (52.362213, 4.943723)
# (52.3616854, 4.9397223)
# (52.353489, 4.930963)
# (52.350859, 4.935164)
# (52.365925, 4.927672)
# (52.365812, 4.932676)
# (52.364327, 4.937667)
# (52.373816, 4.894051)
# (52.3698, 4.892378)
# (52.357072, 4.890701)
# (52.341126, 4.857697)
# (52.3566715, 4.8796365)
# (52.355548, 4.786911)
# (52.356492, 4.791584)
# (52.358004, 4.799095)
# (52.359418, 4.803203)
# (52.359622, 4.807557)
# (52.368807, 4.877952)
# (52.370886, 4.870333)
# (52.35151, 4.856596)
# (52.351584, 4.845329)
# (52.346463, 4.816059)
# (52.34636, 4.81092)
# (52.344996, 4.803954)
# (52.356018, 4.8707)
# (52.353226, 4.863504)
# (52.351551, 4.840877)
# (52.346694, 4.824626)
# (52.349164, 4.827477)
# (52.351309, 4.849935)
# (52.3585511, 4.878272)
# (52.342904, 4.876771)
# (52.347097, 4.876902)
# (52.346736, 4.872528)
# (52.35095, 5.004301)
# (52.357213, 4.927077)
# (52.377247, 4.913021)
# (52.376122, 4.921578)
# (52.372026, 4.96151)
# (52.362993, 4.980435)
# (52.357584, 4.990809)
# (52.355237, 4.995222)
# (52.352886, 4.99964)
# (52.388067, 4.885239)
# (52.358589, 4.91704)
# (52.377477, 4.8784651)
# (52.346245, 4.904905)
# (52.357323, 4.909558)
# (52.351688, 4.903209)
# (52.347096, 4.910978)
# (52.3609356, 4.932944)
# (52.378542, 4.875341)
# (52.349068, 4.904193)
# (52.358356, 4.913602)
# (52.354823, 4.901243)
# (52.353255, 4.894581)
# (52.363839, 4.898296)
# (52.362122, 4.898983)
# (52.359524, 4.898756)
# (52.340165, 4.873144)
# (52.33143, 4.868837)
# (52.338103, 4.868696)
# (52.321631, 4.869149)
# (52.343958, 4.856892)
# (52.312372, 4.872228)
# (52.308284, 4.872508)
# (52.357894, 4.834373)
# (52.395182, 4.85083)
# (52.296347, 4.989227)
# (52.331754, 4.917802)
# (52.295619, 4.974164)
# (52.388603, 4.838885)
# (52.373127, 4.835498)
# (52.378837, 4.83788)
# (52.346543, 4.834481)
# (52.351505, 4.834334)
# (52.364866, 4.833949)
# (52.338394, 4.857271)
# (52.337006, 4.890724)
# (52.318424, 4.941468)
# (52.312132, 4.947191)
# (52.3068, 4.952102)
# (52.298182, 4.95998)
# (52.323607, 4.936487)
# (52.3349118, 4.8683844)
# (52.325405, 4.868966)
# (52.340042, 4.920966)
# (52.378027, 4.899773)
# (52.367349, 4.902401)
# (52.361173, 4.907978)
# (52.354333, 4.912123)
# (52.345272, 4.858524)
# (52.34634, 4.866257)
# (52.349099, 4.877276)
# (52.37192, 4.901301)
# (52.346663, 4.918297)
# (52.329678, 4.9303)
# (52.328624, 4.966759)
# (52.323631, 4.973044)
# (52.316618, 4.979454)
# (52.311035, 4.984549)
# (52.326737, 4.946229)
# (52.364725, 4.859676)
# (52.367174, 4.852482)
# (52.371499, 4.859967)
# (52.340165, 4.873144)
# (52.357894, 4.834373)
# (52.388603, 4.838885)
# (52.373127, 4.835498)
# (52.378837, 4.83788)
# (52.351505, 4.834334)
# (52.338394, 4.857271)
# (52.337006, 4.890724)
# (52.378027, 4.899773)
# (52.367349, 4.902401)
# (52.361173, 4.907978)
# (52.346663, 4.918297)
# (52.33027, 4.956447)
# (52.368939, 4.968961)
# (52.340218, 4.891987)
# (52.388902, 4.918652)
# (52.401877, 4.932229)
# (52.3698, 4.892378)
# (52.359632, 4.890943)
# (52.35279, 4.891107)
# (52.3588611, 4.8812322)
# (52.3746846, 4.8727694)
# (52.3361529, 4.8893095)
# (52.3743398, 4.8764506)
# (52.3727671, 4.8488625)
# (52.3771294, 4.8578315)
# (52.3351784, 4.8598291)
# (52.3164517, 4.8703396)
# (52.3029039, 4.8717813)
# (52.3830358, 4.8820335)
# (52.3651306, 4.9154802)
# (52.2965852, 4.8677556)
# (52.2901479, 4.8636541)
# (52.2810117, 4.8571498)
# (52.2805421, 4.8518489)
# (52.2832311, 4.8454439)
# (52.2822746, 4.8324823)
# (52.2745937, 4.8307936)
# (52.2489605, 4.8117474)
# (52.2431347, 4.8213202)
# (52.2352001, 4.8343674)
# (52.3745745, 4.891494)
# (52.3574222, 4.8994521)

# %%
# Out:
# '<?xml version="1.0"?>\n<Capabilities xmlns="http://www.opengis.net/wmts/1.0" xmlns:ows="http://www.opengis.net/ows/1.1" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:gml="http://www.opengis.net/gml" xsi:schemaLocation="http://www.opengis.net/wmts/1.0 http://schemas.opengis.net/wmts/1.0/wmtsGetCapabilities_response.xsd" version="1.0.0">\n  <ows:ServiceIdentification>\n    <ows:Title>Data en Informatie Amsterdam</ows:Title>\n    <ows:Abstract>Map tile service Gemeente Amsterdam</ows:Abstract>\n    <ows:ServiceType>OGC WMTS</ows:ServiceType>\n    <ows:ServiceTypeVersion>1.0.0</ows:ServiceTypeVersion>\n    <ows:Fees>none</ows:Fees>\n    <ows:AccessConstraints>none</ows:AccessConstraints>\n  </ows:ServiceIdentification>\n  <ows:ServiceProvider>\n    <ows:ProviderName>Gemeente Amsterdam</ows:ProviderName>\n    <ows:ProviderSite xlink:href="https://data.amsterdam.nl/"/>\n    <ows:ServiceContact>\n      <ows:IndividualName>n/a</ows:IndividualName>\n      <ows:PositionName>n/a</ows:PositionName>\n      <ows:ContactInfo>\n        <ows:Phone>\n          <ows:Voice>n/a</ows:Voice>\n          <ows:Facsimile>n/a</ows:Facsimile>\n        </ows:Phone>\n        <ows:Address>\n          <ows:DeliveryPoint>Gemeente Amsterdam</ows:DeliveryPoint>\n          <ows:City>Amsterdam</ows:City>\n          <ows:PostalCode>n/a</ows:PostalCode>\n          <ows:Country>Netherlands</ows:Country>\n          <ows:ElectronicMailAddress>datapunt@amsterdam.nl</ows:ElectronicMailAddress>\n        </ows:Address>\n      </ows:ContactInfo>\n    </ows:ServiceContact>\n  </ows:ServiceProvider>\n  <ows:OperationsMetadata>\n    <ows:Operation name="GetCapabilities">\n      <ows:DCP>\n        <ows:HTTP>\n          <ows:Get xlink:href="https://map.data.amsterdam.nl/service/?">\n            <ows:Constraint name="GetEncoding">\n              <ows:AllowedValues>\n                <ows:Value>KVP</ows:Value>\n              </ows:AllowedValues>\n            </ows:Constraint>\n          </ows:Get>\n        </ows:HTTP>\n      </ows:DCP>\n    </ows:Operation>\n    <ows:Operation name="GetTile">\n      <ows:DCP>\n        <ows:HTTP>\n          <ows:Get xlink:href="https://map.data.amsterdam.nl/service/?">\n            <ows:Constraint name="GetEncoding">\n              <ows:AllowedValues>\n                <ows:Value>KVP</ows:Value>\n              </ows:AllowedValues>\n            </ows:Constraint>\n          </ows:Get>\n        </ows:HTTP>\n      </ows:DCP>\n    </ows:Operation>\n    <ows:Operation name="GetFeatureInfo">\n      <ows:DCP>\n        <ows:HTTP>\n          <ows:Get xlink:href="https://map.data.amsterdam.nl/service/?">\n            <ows:Constraint name="GetEncoding">\n              <ows:AllowedValues>\n                <ows:Value>KVP</ows:Value>\n              </ows:AllowedValues>\n            </ows:Constraint>\n          </ows:Get>\n        </ows:HTTP>\n      </ows:DCP>\n    </ows:Operation>\n  </ows:OperationsMetadata>\n  <Contents>\n    <Layer>\n      <ows:Title>Basiskaart Amsterdam (Rijksdriehoeksstelsel)</ows:Title>\n      <ows:Abstract></ows:Abstract>\n      <ows:WGS84BoundingBox>\n        <ows:LowerCorner>-1.6572916026074758 48.04050187220451</ows:LowerCorner>\n        <ows:UpperCorner>12.431727264736635 56.11058964552854</ows:UpperCorner>\n      </ows:WGS84BoundingBox>\n      <ows:Identifier>topografie</ows:Identifier>\n      <Style>\n        <ows:Identifier>default</ows:Identifier>\n      </Style>\n      <Format>image/png</Format>\n      <TileMatrixSetLink>\n        <TileMatrixSet>nl_grid</TileMatrixSet>\n      </TileMatrixSetLink>\n    </Layer>\n    <Layer>\n      <ows:Title>Basiskaart Amsterdam (Rijksdriehoeksstelsel)</ows:Title>\n      <ows:Abstract></ows:Abstract>\n      <ows:WGS84BoundingBox>\n        <ows:LowerCorner>-1.6572916026074758 48.04050187220451</ows:LowerCorner>\n        <ows:UpperCorner>12.431727264736635 56.11058964552854</ows:UpperCorner>\n      </ows:WGS84BoundingBox>\n      <ows:Identifier> ...
