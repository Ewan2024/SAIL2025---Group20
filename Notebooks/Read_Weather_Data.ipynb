# %%
import pandas as pd
import re

# %%
# Read in weather data
weather_data = pd.read_csv(
    '/Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/data/weather_data.csv',
    encoding='ISO-8859-1'   # or 'latin1'
)

# %%
weather_data.head()
# Out:
#       Date      Time Temperature Dew Point Humidity Wind Wind Speed Wind Gust  \
# 0  20/8/25  12:25 AM       63Ê¡F     55Ê¡F     77Ê%    N      8Êmph     0Êmph
# 1  20/8/25  12:55 AM       63Ê¡F     55Ê¡F     77Ê%  NNE     12Êmph     0Êmph
# 2  20/8/25   1:25 AM       63Ê¡F     55Ê¡F     77Ê%    N     10Êmph     0Êmph
# 3  20/8/25   1:55 AM       63Ê¡F     55Ê¡F     77Ê%  NNE      9Êmph     0Êmph
# 4  20/8/25   2:25 AM       63Ê¡F     55Ê¡F     77Ê%  NNE      6Êmph     0Êmph
#
#    Pressure Precip.      Condition
# 0  29.96Êin  0.0Êin  Mostly Cloudy
# 1  29.96Êin  0.0Êin  Mostly Cloudy
# 2  29.96Êin  0.0Êin  Mostly Cloudy
# 3  29.96Êin  0.0Êin  Mostly Cloudy
# 4  29.96Êin  0.0Êin  Mostly Cloudy

# %%
# clean column names
weather_data.columns = (
    weather_data.columns.str.strip()
                   .str.lower()
                   .str.replace(' ', '_')
)

# %%
weather_data.head()
# Out:
#       date      time temperature dew_point humidity wind wind_speed wind_gust  \
# 0  20/8/25  12:25 AM       63Ê¡F     55Ê¡F     77Ê%    N      8Êmph     0Êmph
# 1  20/8/25  12:55 AM       63Ê¡F     55Ê¡F     77Ê%  NNE     12Êmph     0Êmph
# 2  20/8/25   1:25 AM       63Ê¡F     55Ê¡F     77Ê%    N     10Êmph     0Êmph
# 3  20/8/25   1:55 AM       63Ê¡F     55Ê¡F     77Ê%  NNE      9Êmph     0Êmph
# 4  20/8/25   2:25 AM       63Ê¡F     55Ê¡F     77Ê%  NNE      6Êmph     0Êmph
#
#    pressure precip.      condition
# 0  29.96Êin  0.0Êin  Mostly Cloudy
# 1  29.96Êin  0.0Êin  Mostly Cloudy
# 2  29.96Êin  0.0Êin  Mostly Cloudy
# 3  29.96Êin  0.0Êin  Mostly Cloudy
# 4  29.96Êin  0.0Êin  Mostly Cloudy

# %%
# Remove unwanted characters
def clean_text(x):
    if isinstance(x, str):
        # Remove non-ASCII characters (Ê, ¡, °, etc.)
        x = re.sub(r'[^\x00-\x7F]+', '', x)
        return x.strip()
    return x

weather_data = weather_data.applymap(clean_text)
# Out:
# /var/folders/r7/j4cx6h396gqdzk5s_4h9vf180000gn/T/ipykernel_66596/1621821120.py:9: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weather_data = weather_data.applymap(clean_text)

# %%
weather_data.head()
# Out:
#       date      time temperature dew_point humidity wind wind_speed wind_gust  \
# 0  20/8/25  12:25 AM         63F       55F      77%    N       8mph      0mph
# 1  20/8/25  12:55 AM         63F       55F      77%  NNE      12mph      0mph
# 2  20/8/25   1:25 AM         63F       55F      77%    N      10mph      0mph
# 3  20/8/25   1:55 AM         63F       55F      77%  NNE       9mph      0mph
# 4  20/8/25   2:25 AM         63F       55F      77%  NNE       6mph      0mph
#
#   pressure precip.      condition
# 0  29.96in   0.0in  Mostly Cloudy
# 1  29.96in   0.0in  Mostly Cloudy
# 2  29.96in   0.0in  Mostly Cloudy
# 3  29.96in   0.0in  Mostly Cloudy
# 4  29.96in   0.0in  Mostly Cloudy

# %%
# Convert numeric columns

def extract_number(s):
    """Extract first float or int number from a string."""
    if isinstance(s, str):
        match = re.search(r'[-+]?\d*\.?\d+', s)
        if match:
            return float(match.group())
    return pd.NA

numeric_cols = ['temperature', 'dew_point', 'humidity', 'wind_speed', 'wind_gust', 'pressure', 'precip.']
for col in numeric_cols:
    weather_data[col] = weather_data[col].apply(extract_number)

# %%
weather_data.head()
# Out:
#       date      time  temperature  dew_point  humidity wind  wind_speed  \
# 0  20/8/25  12:25 AM         63.0       55.0      77.0    N         8.0
# 1  20/8/25  12:55 AM         63.0       55.0      77.0  NNE        12.0
# 2  20/8/25   1:25 AM         63.0       55.0      77.0    N        10.0
# 3  20/8/25   1:55 AM         63.0       55.0      77.0  NNE         9.0
# 4  20/8/25   2:25 AM         63.0       55.0      77.0  NNE         6.0
#
#    wind_gust  pressure  precip.      condition
# 0        0.0     29.96      0.0  Mostly Cloudy
# 1        0.0     29.96      0.0  Mostly Cloudy
# 2        0.0     29.96      0.0  Mostly Cloudy
# 3        0.0     29.96      0.0  Mostly Cloudy
# 4        0.0     29.96      0.0  Mostly Cloudy

# %%
# convert date + time into datetime

weather_data['timestamp'] = pd.to_datetime(
    weather_data['date'] + ' ' + weather_data['time'],
    format='%d/%m/%y %I:%M %p',
    errors='coerce'
)

# %%
weather_data.head()
# Out:
#       date      time  temperature  dew_point  humidity wind  wind_speed  \
# 0  20/8/25  12:25 AM         63.0       55.0      77.0    N         8.0
# 1  20/8/25  12:55 AM         63.0       55.0      77.0  NNE        12.0
# 2  20/8/25   1:25 AM         63.0       55.0      77.0    N        10.0
# 3  20/8/25   1:55 AM         63.0       55.0      77.0  NNE         9.0
# 4  20/8/25   2:25 AM         63.0       55.0      77.0  NNE         6.0
#
#    wind_gust  pressure  precip.      condition           timestamp
# 0        0.0     29.96      0.0  Mostly Cloudy 2025-08-20 00:25:00
# 1        0.0     29.96      0.0  Mostly Cloudy 2025-08-20 00:55:00
# 2        0.0     29.96      0.0  Mostly Cloudy 2025-08-20 01:25:00
# 3        0.0     29.96      0.0  Mostly Cloudy 2025-08-20 01:55:00
# 4        0.0     29.96      0.0  Mostly Cloudy 2025-08-20 02:25:00

# %%
# Drop unneeded columns or reorder 
weather_data = weather_data[['timestamp', 'temperature', 'dew_point', 'humidity',
                   'wind_speed', 'wind_gust', 'pressure', 'precip.', 'condition']]

# %%
weather_data.tail()
# Out:
#               timestamp  temperature  dew_point  humidity  wind_speed  \
# 235 2025-08-24 21:55:00         61.0       54.0      77.0         2.0
# 236 2025-08-24 22:25:00         61.0       52.0      72.0         1.0
# 237 2025-08-24 22:55:00         59.0       52.0      77.0         1.0
# 238 2025-08-24 23:25:00         57.0       54.0      88.0         1.0
# 239 2025-08-24 23:55:00         57.0       54.0      88.0         1.0
#
#      wind_gust  pressure  precip. condition
# 235        0.0     30.16      0.0      Fair
# 236        0.0     30.16      0.0      Fair
# 237        0.0     30.16      0.0      Fair
# 238        0.0     30.13      0.0      Fair
# 239        0.0     30.13      0.0      Fair

# %%
# Rename Precip. column
weather_data.rename(columns={'precip.': 'precipitation'}, inplace=True)

# %%
weather_data.head()
# Out:
#             timestamp  temperature  dew_point  humidity  wind_speed  \
# 0 2025-08-20 00:25:00         63.0       55.0      77.0         8.0
# 1 2025-08-20 00:55:00         63.0       55.0      77.0        12.0
# 2 2025-08-20 01:25:00         63.0       55.0      77.0        10.0
# 3 2025-08-20 01:55:00         63.0       55.0      77.0         9.0
# 4 2025-08-20 02:25:00         63.0       55.0      77.0         6.0
#
#    wind_gust  pressure  precipitation      condition
# 0        0.0     29.96            0.0  Mostly Cloudy
# 1        0.0     29.96            0.0  Mostly Cloudy
# 2        0.0     29.96            0.0  Mostly Cloudy
# 3        0.0     29.96            0.0  Mostly Cloudy
# 4        0.0     29.96            0.0  Mostly Cloudy

# %%
# convert to metric
# Fahrenheit to Celsius
weather_data['temperature'] = (weather_data['temperature'] - 32) * 5 / 9
weather_data['dew_point'] = (weather_data['dew_point'] - 32) * 5 / 9
# mph to m/s
weather_data['wind_speed'] = weather_data['wind_speed'] * 0.44704
weather_data['wind_gust'] = weather_data['wind_gust'] * 0.44704
# in to hPa (1 inch Hg = 33.8639 hPa)
weather_data['pressure'] = weather_data['pressure'] * 33.8639
# inches to mm
weather_data['precipitation'] = weather_data['precipitation'] * 25.4

# %%
weather_data
# Out:
#               timestamp  temperature  dew_point  humidity  wind_speed  \
# 0   2025-08-20 00:25:00    17.222222  12.777778      77.0     3.57632
# 1   2025-08-20 00:55:00    17.222222  12.777778      77.0     5.36448
# 2   2025-08-20 01:25:00    17.222222  12.777778      77.0     4.47040
# 3   2025-08-20 01:55:00    17.222222  12.777778      77.0     4.02336
# 4   2025-08-20 02:25:00    17.222222  12.777778      77.0     2.68224
# ..                  ...          ...        ...       ...         ...
# 235 2025-08-24 21:55:00    16.111111  12.222222      77.0     0.89408
# 236 2025-08-24 22:25:00    16.111111  11.111111      72.0     0.44704
# 237 2025-08-24 22:55:00    15.000000  11.111111      77.0     0.44704
# 238 2025-08-24 23:25:00    13.888889  12.222222      88.0     0.44704
# 239 2025-08-24 23:55:00    13.888889  12.222222      88.0     0.44704
#
#      wind_gust     pressure  precipitation      condition
# 0          0.0  1014.562444            0.0  Mostly Cloudy
# 1          0.0  1014.562444            0.0  Mostly Cloudy
# 2          0.0  1014.562444            0.0  Mostly Cloudy
# 3          0.0  1014.562444            0.0  Mostly Cloudy
# 4          0.0  1014.562444            0.0  Mostly Cloudy
# ..         ...          ...            ...            ...
# 235        0.0  1021.335224            0.0           Fair
# 236        0.0  1021.335224            0.0           Fair
# 237        0.0  1021.335224            0.0           Fair
# 238        0.0  1020.319307            0.0           Fair
# 239        0.0  1020.319307            0.0           Fair
#
# [240 rows x 9 columns]

# %%
weather_data['timestamp'] = pd.to_datetime(weather_data['timestamp']).dt.tz_localize('Europe/Amsterdam', nonexistent='shift_forward')

# %%
weather_data.head()
# Out:
#                   timestamp  temperature  dew_point  humidity  wind_speed  \
# 0 2025-08-20 00:25:00+02:00    17.222222  12.777778      77.0     3.57632
# 1 2025-08-20 00:55:00+02:00    17.222222  12.777778      77.0     5.36448
# 2 2025-08-20 01:25:00+02:00    17.222222  12.777778      77.0     4.47040
# 3 2025-08-20 01:55:00+02:00    17.222222  12.777778      77.0     4.02336
# 4 2025-08-20 02:25:00+02:00    17.222222  12.777778      77.0     2.68224
#
#    wind_gust     pressure  precipitation      condition
# 0        0.0  1014.562444            0.0  Mostly Cloudy
# 1        0.0  1014.562444            0.0  Mostly Cloudy
# 2        0.0  1014.562444            0.0  Mostly Cloudy
# 3        0.0  1014.562444            0.0  Mostly Cloudy
# 4        0.0  1014.562444            0.0  Mostly Cloudy

# %%
weather_data.to_csv(
    '/Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/data/weather_data_cleaned.csv',
    index=False
)
