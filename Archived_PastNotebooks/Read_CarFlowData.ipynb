# %%
import pandas as pd
# copy relative path by right-clicking the file name on the explorer
car_flow_data = pd.read_parquet('/Users/sheikharfahmi/Desktop/TIL_Python_Programming/SAIL2025---Group20/data/20250820163000_stream.tomtom.analyze-sail.parquet', engine='fastparquet')

# %%
car_flow_data.head()
# Out:
#        _timestamp                      _topic  \
# 0  1755671789.749  stream.tomtom.analyze-sail
# 1  1755671833.722  stream.tomtom.analyze-sail
# 2  1755671877.859  stream.tomtom.analyze-sail
# 3  1755671921.969  stream.tomtom.analyze-sail
# 4  1755671966.192  stream.tomtom.analyze-sail
#
#                                               _value  \
# 0  \nߒ\n{"time": "2025-08-20T08:36:29.749039+02:0...
# 1  0AA2920A7B2274696D65223A2022323032352D30382D32...
# 2  0A81940A7B2274696D65223A2022323032352D30382D32...
# 3  0A8D950A7B2274696D65223A2022323032352D30382D32...
# 4  0AF1950A7B2274696D65223A2022323032352D30382D32...
#
#                                    _key _offset _partition _connector_id  \
# 0  \n\n\n\nanalyze-01"testmytest  345072          4          None
# 1  \n\n\n\nanalyze-01"testmytest  345073          4          None
# 2  \n\n\n\nanalyze-01"testmytest  345074          4          None
# 3  \n\n\n\nanalyze-01"testmytest  345075          4          None
# ...
